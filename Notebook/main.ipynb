# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv',header=1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes    Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN     1.0
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN     1.0

# %%
df[['Region']]=df[['Region']].astype('int')

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df=df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df=df.drop(122).reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df[['day','month','year','Temperature','RH','Ws']]=df[['day','month','year','Temperature','RH','Ws']].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.6+ KB

# %%
objects=[features for features in df.columns if df[features].dtypes=='O']

# %%
objects
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
for i in objects:
    if i!='Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# std      2.003207   14.349641   12.393040   47.665606    4.154234   14.228421
# min      0.000000   28.600000    0.700000    6.900000    0.000000    1.100000
# 25%      0.000000   71.850000    5.800000   12.350000    1.400000    6.000000
# 50%      0.000000   83.300000   11.300000   33.100000    3.500000   12.400000
# 75%      0.500000   88.300000   20.800000   69.100000    7.250000   22.650000
# max     16.800000   96.000000   65.900000  220.400000   19.000000   68.000000
#
#               FWI      Region
# count  243.000000  243.000000
# mean     7.035391    0.497942
# std      7.440568    0.501028
# min      0.000000    0.000000
# 25%      0.700000    0.000000
# 50%      4.200000    0.000000
# 75%     11.450000    1.000000
# max     31.100000    1.000000

# %%
df.to_csv('Algerian_forest_fires_dataset_Cleaned_dataset.csv',index=False)

# %%
df_copy=df

# %%
df_copy["Classes"].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df_copy["Classes"]=np.where(df_copy["Classes"].str.contains("not fire"),0,1)

# %%
df_copy.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes  Region
# 0  0.5        0       0
# 1  0.4        0       0
# 2  0.1        0       0
# 3  0.0        0       0
# 4  0.5        0       0

# %%
df_copy["Classes"].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/numpy124/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
plt.style.use('seaborn-v0_8')
df_copy.hist(bins=50, figsize=(20,15))
plt.show()

# %%
percentages = df_copy["Classes"].value_counts(normalize=True) * 100
print(percentages)
# Out:
# Classes
# 1    56.378601
# 0    43.621399
# Name: proportion, dtype: float64

# %%
classlabels=['fire','not fire']
plt.figure(figsize=(12,7))
plt.pie(percentages, labels=classlabels, autopct='%1.1f%%')
plt.title('Pie chart of classes')
plt.show()

# %%
df_copy.corr()
# Out:
#                   day     month  year  Temperature        RH        Ws  \
# day          1.000000 -0.000369   NaN     0.097227 -0.076034  0.047812
# month       -0.000369  1.000000   NaN    -0.056781 -0.041252 -0.039880
# year              NaN       NaN   NaN          NaN       NaN       NaN
# Temperature  0.097227 -0.056781   NaN     1.000000 -0.651400 -0.284510
# RH          -0.076034 -0.041252   NaN    -0.651400  1.000000  0.244048
# Ws           0.047812 -0.039880   NaN    -0.284510  0.244048  1.000000
# Rain        -0.112523  0.034822   NaN    -0.326492  0.222356  0.171506
# FFMC         0.224956  0.017030   NaN     0.676568 -0.644873 -0.166548
# DMC          0.491514  0.067943   NaN     0.485687 -0.408519 -0.000721
# DC           0.527952  0.126511   NaN     0.376284 -0.226941  0.079135
# ISI          0.180543  0.065608   NaN     0.603871 -0.686667  0.008532
# BUI          0.517117  0.085073   NaN     0.459789 -0.353841  0.031438
# FWI          0.350781  0.082639   NaN     0.566670 -0.580957  0.032368
# Classes      0.202840  0.024004   NaN     0.516015 -0.432161 -0.069964
# Region       0.000821  0.001857   NaN     0.269555 -0.402682 -0.181160
#
#                  Rain      FFMC       DMC        DC       ISI       BUI  \
# day         -0.112523  0.224956  0.491514  0.527952  0.180543  0.517117
# month        0.034822  0.017030  0.067943  0.126511  0.065608  0.085073
# year              NaN       NaN       NaN       NaN       NaN       NaN
# Temperature -0.326492  0.676568  0.485687  0.376284  0.603871  0.459789
# RH           0.222356 -0.644873 -0.408519 -0.226941 -0.686667 -0.353841
# Ws           0.171506 -0.166548 -0.000721  0.079135  0.008532  0.031438
# Rain         1.000000 -0.543906 -0.288773 -0.298023 -0.347484 -0.299852
# FFMC        -0.543906  1.000000  0.603608  0.507397  0.740007  0.592011
# DMC         -0.288773  0.603608  1.000000  0.875925  0.680454  0.982248
# DC          -0.298023  0.507397  0.875925  1.000000  0.508643  0.941988
# ISI         -0.347484  0.740007  0.680454  0.508643  1.000000  0.644093
# BUI         -0.299852  0.592011  0.982248  0.941988  0.644093  1.000000
# FWI         -0.324422  0.691132  0.875864  0.739521  0.922895  0.857973
# Classes     -0.379097  0.769492  0.585658  0.511123  0.735197  0.586639
# Region      -0.040013  0.222241  0.192089 -0.078734  0.263197  0.089408
#
#                   FWI   Classes    Region
# day          0.350781  0.202840  0.000821
# month        0.082639  0.024004  0.001857
# year              NaN       NaN       NaN
# Temperature  0.566670  0.516015  0.269555
# RH          -0.580957 -0.432161 -0.402682
# Ws           0.032368 -0.069964 -0.181160
# Rain        -0.324422 -0.379097 -0.040013
# FFMC         0.691132  0.769492  0.222241
# DMC          0.875864  0.585658  0.192089
# DC           0.739521  0.511123 -0.078734
# ISI          0.922895  0.735197  0.263197
# BUI          0.857973  0.586639  0.089408
# FWI          1.000000  0.719216  0.197102
# Classes      0.719216  1.000000  0.162347
# Region       0.197102  0.162347  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(df['FWI'],color='green')
# Out:
# <Axes: ylabel='FWI'>

# %%
df['Classes'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Classes, dtype: int64

# %%
df_copy["Classes"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Classes, dtype: int64

# %%
df_copy=df_copy.drop(columns=['day','month','year'],axis=1)

# %%
X = df_copy.drop(['FWI'], axis=1)
y= df_copy['FWI']

# %%
X
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4        0       0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9        0       0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7        0       0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7        0       0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9        0       0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...      ...     ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1       1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2        0       1
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4        0       1
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1        0       1
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8        0       1
#
# [243 rows x 11 columns]

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((182, 11), (61, 11), (182,), (61,))

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# Temperature  0.390684  0.629848  0.473609  0.542141  0.254549
# RH          -0.236078 -0.717804 -0.362317 -0.456876 -0.394665
# Ws           0.096576 -0.023558  0.035633 -0.082570 -0.199969
# Rain        -0.302341 -0.345707 -0.300964 -0.369357 -0.059022
# FFMC         0.524101  0.750799  0.607210  0.781259  0.249514
# DMC          0.868647  0.685656  0.983175  0.617273  0.212582
# DC           1.000000  0.513701  0.942414  0.543581 -0.060838
# ISI          0.513701  1.000000  0.643818  0.742977  0.296441
# BUI          0.942414  0.643818  1.000000  0.612239  0.114897
# Classes      0.543581  0.742977  0.612239  1.000000  0.188837
# Region      -0.060838  0.296441  0.114897  0.188837  1.000000

# %%
plt.Figure(figsize=(10, 8))
corr=X_train.corr()
sns.heatmap(corr, annot=True)
plt.title('Correlation Heatmap of Features')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Features')

# %%
def correlation(data,thresold):
    col_corr=set() # Set of all the names of correlated columns
    corr_matrix=data.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>thresold: # we are interested in absolute values
                colname=corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.85)

# %%
corr_features
# Out:
# {'BUI', 'DC'}

# %%
X_train.drop(columns=corr_features, inplace=True)

# %%
X_test.drop(columns=corr_features, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  
X_test_scaled = scaler.transform(X_test)

# %%
plt.subplots(figsize=(15, 5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('X_train before training')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train after training')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
regression = LinearRegression()
regression.fit(X_train_scaled, y_train)
y_pred = regression.predict(X_test_scaled)
mae= mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
print(f'R^2 Score: {score}')
plt.scatter (y_test, y_pred)
# Out:
# Mean Absolute Error: 0.5468236465249998
# R^2 Score: 0.9847657384266951

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(X_train_scaled, y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
print(f'R^2 Score: {score}')
plt.scatter (y_test, y_pred)
# Out:
# Mean Absolute Error: 1.1331759949144087
# R^2 Score: 0.9492020263112388

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV()
lassocv.fit(X_train_scaled, y_train)
# Out:
# LassoCV()

# %%
lassocv.alpha_
# Out:
# 0.05725391318234408

# %%
lassocv.alphas_
# Out:
# array([7.05853002, 6.58280872, 6.13914944, 5.72539132, 5.33951911,
#        [ 0.70847636,  1.50819995,  7.96151575,  1.914521  ,  0.8098638 ],
#        [ 0.70814046,  1.50740984,  7.97034636,  1.91358558,  0.81227152],
#        [ 0.70789298,  1.5065737 ,  7.97838619,  1.91277526,  0.81468439],
#        [ 0.70770357,  1.50591279,  7.98587605,  1.9120262 ,  0.8170304 ],
#        [ 0.70752166,  1.50536216,  7.99241057,  1.91138883,  0.81925406],
#        [ 0.70734296,  1.50487616,  7.99849196,  1.91084915,  0.82119901],
#        [ 0.70724307,  1.50444309,  8.00451482,  1.91033293,  0.82327046],
#        [ 0.70719344,  1.50391791,  8.01011355,  1.9098903 ,  0.8250587 ],
#        [ 0.70714379,  1.50342997,  8.01481494,  1.90951275,  0.826765  ],
#        [ 0.70711086,  1.50300182,  8.01992921,  1.90919915,  0.82842365]])

# %%
y_pred = lassocv.predict(X_test_scaled)
plt.scatter(y_test, y_pred)
mae= mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
print(f'R^2 Score: {score}')
# Out:
# Mean Absolute Error: 0.6199701158263436
# R^2 Score: 0.9820946715928274

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, r2_score
ridge = Ridge()
ridge.fit(X_train_scaled, y_train)
y_pred = ridge.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
print(f'R^2 Score: {score}')
plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error: 0.5642305340105709
# R^2 Score: 0.9842993364555513

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV(cv=5)
ridgecv.fit(X_train_scaled, y_train)
y_pred = ridgecv.predict(X_test_scaled)
plt.scatter(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)

# %%
ridgecv.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': None,
#  'store_cv_values': 'deprecated'}

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error, r2_score
elasticnet = ElasticNet()
elasticnet.fit(X_train_scaled, y_train)
y_pred = elasticnet.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
print(f'R^2 Score: {score}')
plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error: 1.8822353634896
# R^2 Score: 0.8753460589519703

# %%
from sklearn.linear_model import ElasticNetCV
elasticnetcv = ElasticNetCV(cv=5)
elasticnetcv.fit(X_train_scaled, y_train)
y_pred = elasticnetcv.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
print(f'R^2 Score: {score}')
plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error: 0.6575946731430898
# R^2 Score: 0.9814217587854941

# %%
scaler
# Out:
# StandardScaler()

# %%
ridge
# Out:
# Ridge()

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl', 'wb'))
pickle.dump(ridge,open('ridge.pkl', 'wb'))
